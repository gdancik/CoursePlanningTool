# %% [markdown]
# ### Get policies

# %%
from docx import Document
import copy
import sys
sys.path.append('../')
from backend.services.syllabus_generator import create_syllabus_statment_page

# %%
url = 'https://www.easternct.edu/center-for-teaching-learning-and-assessment/syllabus-statements/index.html'
policies = ['Accommodations', 'Integrity', 'Academic Success']

syllabus_statment_page = Document()
create_syllabus_statment_page(syllabus_statment_page,url, policies)

# %%
syllabus_statment_page.save('/Users/dancikg/Downloads/statements.docx')
