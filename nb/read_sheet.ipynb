# %% [markdown]
# ## Example code for reading a sheet using the /api/getSheet endpoing
#
# Here we read a sheet using the PythonAnywhere API.

# %%
import requests
import json
import pandas as pd

baseurl = 'http://127.0.0.1:5000/'
#baseurl = 'https://gdancik.pythonanywhere.com/'

session = requests.Session()
response = session.get(baseurl + 'api/test_login/?user=annie&password=password')
response.text
# Out:
# '{\n  "name": "annie",\n  "user": "annie"\n}\n'

# %%
response = session.post(baseurl + 'api/getSheet/')
#print(response.text)
sheet = json.loads(response.text)
df = pd.DataFrame.from_dict(sheet, orient = 'index')
df
# Out:
#                      additional_sections_syllabus_json  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud
# Wl2xy3ghfGMeblN2A9hx
# csW0BYumcES5zD9STmt3
# KDxGx8dpqPVaz8jqQkAv                               NaN
#
#                      assmt_assignments_syllabus_json   assmt_communicate  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO                                  assmt_communicate1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud                                  assmt_communicate2
# Wl2xy3ghfGMeblN2A9hx                                  assmt_communicate3
# csW0BYumcES5zD9STmt3                                  assmt_communicate4
# KDxGx8dpqPVaz8jqQkAv                             NaN                 NaN
#
#                        assmt_feedback   assmt_order   assmt_types  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO  assmt_feedback1  assmt_order1  assmt_types1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud  assmt_feedback2  assmt_order2  assmt_types2
# Wl2xy3ghfGMeblN2A9hx  assmt_feedback3  assmt_order3  assmt_types3
# csW0BYumcES5zD9STmt3  assmt_feedback4  assmt_order4  assmt_types4
# KDxGx8dpqPVaz8jqQkAv              NaN           NaN           NaN
#
#                        course_description_syllabus  \
# 0fBVjCYVsxV73bA00a8R          Summary of Responses
# 7aJ2l46UfpEaKzhzpPDO  course_description_syllabus1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud  course_description_syllabus2
# Wl2xy3ghfGMeblN2A9hx  course_description_syllabus3
# csW0BYumcES5zD9STmt3  course_description_syllabus4
# KDxGx8dpqPVaz8jqQkAv                           NaN
#
#                        course_materials_syllabus  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO  course_materials_syllabus1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud  course_materials_syllabus2
# Wl2xy3ghfGMeblN2A9hx  course_materials_syllabus3
# csW0BYumcES5zD9STmt3  course_materials_syllabus4
# KDxGx8dpqPVaz8jqQkAv                         NaN
#
#                                                    course_schedule_list  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud
# Wl2xy3ghfGMeblN2A9hx  [["Day", "Date", "Description"], ["Tuesday", "...
# csW0BYumcES5zD9STmt3
# KDxGx8dpqPVaz8jqQkAv                                                NaN
#
#                                  course_title_syllabus  ...  \
# 0fBVjCYVsxV73bA00a8R                        Algorithms  ...
# 7aJ2l46UfpEaKzhzpPDO         Fundamentals of Computing  ...
# BwA5QK3Gec5Ink8uHRoT                   Data Structures  ...
# QZsNAyntguWy3YIC83Ud  Computer Science & Programming I  ...
# Wl2xy3ghfGMeblN2A9hx                            Calc I  ...
# csW0BYumcES5zD9STmt3                           Calc II  ...
# KDxGx8dpqPVaz8jqQkAv                              test  ...
#
#                        office_hours_syllabus   office_location_syllabus  \
# 0fBVjCYVsxV73bA00a8R              MWF 2-2:50           Science Room 232
# 7aJ2l46UfpEaKzhzpPDO  office_hours_syllabus1  office_location_syllabus1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud  office_hours_syllabus2  office_location_syllabus2
# Wl2xy3ghfGMeblN2A9hx  office_hours_syllabus3  office_location_syllabus3
# csW0BYumcES5zD9STmt3  office_hours_syllabus4  office_location_syllabus4
# KDxGx8dpqPVaz8jqQkAv                     NaN                        NaN
#
#                        phone_syllabus  \
# 0fBVjCYVsxV73bA00a8R     860-121-1212
# 7aJ2l46UfpEaKzhzpPDO  phone_syllabus1
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud  phone_syllabus2
# Wl2xy3ghfGMeblN2A9hx  phone_syllabus3
# csW0BYumcES5zD9STmt3  phone_syllabus4
# KDxGx8dpqPVaz8jqQkAv              NaN
#
#                                                    policy_statements  \
# 0fBVjCYVsxV73bA00a8R
# 7aJ2l46UfpEaKzhzpPDO
# BwA5QK3Gec5Ink8uHRoT
# QZsNAyntguWy3YIC83Ud
# Wl2xy3ghfGMeblN2A9hx  ["academic_integrity", "diversity", "weather"]
# csW0BYumcES5zD9STmt3
# KDxGx8dpqPVaz8jqQkAv                                             NaN
#
#                      subj_code_syllabus term_syllabus   times1_syllabus  \
# 0fBVjCYVsxV73bA00a8R                CSC          Fall            1-1:50
# 7aJ2l46UfpEaKzhzpPDO                CSC        Spring    9:00 - 9:50 AM
# BwA5QK3Gec5Ink8uHRoT                CSC        Summer
# QZsNAyntguWy3YIC83Ud                CSC          Fall  10:00 - 10:50 AM
# Wl2xy3ghfGMeblN2A9hx                MAT          Fall   9:30 - 10:45 AM
# csW0BYumcES5zD9STmt3                MAT        Spring    2:00 - 2:50 PM
# KDxGx8dpqPVaz8jqQkAv                csc        Winter               NaN
#
#                        times2_syllabus university_resources year_syllabus
# 0fBVjCYVsxV73bA00a8R                                                 2025
# 7aJ2l46UfpEaKzhzpPDO  times2_syllabus1                               2025
# BwA5QK3Gec5Ink8uHRoT                                                 2025
# QZsNAyntguWy3YIC83Ud  times2_syllabus2                               Fall
# Wl2xy3ghfGMeblN2A9hx                      ["math_tutoring"]          Fall
# csW0BYumcES5zD9STmt3  times2_syllabus4                               2026
# KDxGx8dpqPVaz8jqQkAv               NaN                  NaN          2025
#
# [7 rows x 59 columns]

# %%
type(sheet_local[0])

# %%
course_id = 'XHNBYqqdPjLgLWxteLbB'

response = session.post(baseurl + 'api/getCourse/',
                        json = {'course_id': course_id}
)
json.loads(response.text)

# %%
response = session.post(baseurl + 'api/getValue/',
                        json = {'course_id': 'XHNBYqqdPjLgLWxteLbB', 
                                'list_of_columns' : ['instructor_name_syllabus', 'additional_sections_syllabus_json']}
)
json.loads(response.text)

# %%
response = session.post(baseurl + 'api/deleteCourse/',
                        json = {'course_id': 'zdrKSHMmwigvDGtOwUSn'}
                                
)
json.loads(response.text)

# %%
import os
import sys

# Add parent directory to sys.path 
parent_dir = os.path.abspath(os.path.join('.', '..'))
sys.path.insert(0, parent_dir)

from backend.services.firestore_editor import fsEditor
import backend.services.firestore_stats as fs_stats

# %%
fs = fsEditor('annie')

# %%
fs = fsEditor('garrett.dancik@gmail.com')
fs.createNewCourse({
    'subj_code_syllabus': 'CSC',
    'crse_number_syllabus': '450',
    'instructor_title_syllabus': 'Garrett Dancik',
    'email_syllabus': 'dancikg@easternct.edu',
    'course_title_syllabus': 'Senior Research'
})

# %%
sheet = fs.read_collection()

# %%
sorted(sheet.columns)

# %%
docs = fs.client.collection(fs.collection_name).stream()
        
docs = [(doc.id, doc) for doc in docs]
len(docs)

# %%
import pandas as pd
sheet = [{'_course_id': id, **doc.to_dict()} for id, doc in docs]

sheet = pd.DataFrame(sheet)

# %%
sheet.to_dict(orient='index')

# %%
df = pd.DataFrame(sheet).set_index('_course_id', drop = True)
